# %% [markdown]
# # Värmelära

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Film 1 - Laddning, krafter, potential
# 1. Energiprincipen och olika energiformer (0:00 - 8:13)
# 2. Tidspilen, TII, entropi (8:13 - 17:40)
# 3. Värme (17:40 - 19:00)
# 4. Arbete och entropi (19:00 - 22.30)
# 5. Värmedöden (22:30 - 35:55)

# %%
display(YouTubeVideo("GOrWy_yNBvY"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# # Fördjupning

# %% [markdown]
# ## Film 2 - Entropi
# 1. ...

# %%
display(YouTubeVideo("vX_WLrcgikc"))

# %% [markdown]
# #### Anteckningar
# ...
