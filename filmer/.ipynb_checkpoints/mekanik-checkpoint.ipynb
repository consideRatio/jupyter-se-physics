# %% [markdown]
# # Filmer - Mekanik

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Film 1 - Krafter
# 1. Resultanter (motsvarar summa för vektorer) (0:00 - 1:18)
# 2. Komposanter (motsvarar termer för vektorer) (1:18 - 7:33)

# %%
display(YouTubeVideo("Ff_suyHtEXk"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 2 - Newtons lagar
# 1. Newtons lagar (0 - 7:33)
# 2. Kraftmoment (7:33 - 11:36)
# 3. Corioliseffekten (11:36 - 14:22)
# 4. Tillämpning: helikopter (14:22 - 16:08)
# 5. Tillämpning: flygplan (16:08 - 18:30)
# 6. Tillämpning: raketer (18:30 - 19:50)
# 7. Tillämpning: satelliter (19:50 - 21:24)
# 8. Gravitationskraft (21:24 ->)

# %%
display(YouTubeVideo("Ixf9ZyZaE9Q"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 3 - Momentum
# 1.

# %%
display(YouTubeVideo("PNHSIEO-KOQ"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 1 - Energi
# 1. Energiprincipen och olika energiformer (0:00 - 8:13)
# 2. ... Vi fortsätter här i värmeläran (0:00

# %%
display(YouTubeVideo("GOrWy_yNBvY"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 1 - Energi
# 1. Energiprincipen och olika energiformer (0:00 - 8:13)
# 2. ... Vi fortsätter här i värmeläran (0:00

# %%
display(YouTubeVideo("87E0DKs5bok"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# # Fördjupning

# %% [markdown]
# ## Film 1 - Stabilitetsanalys
# 1.

# %%
display(YouTubeVideo("p9qrHdPEe28"))

# %% [markdown]
# #### Anteckningar
# ...
