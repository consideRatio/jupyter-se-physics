# %% [markdown]
# # Filmer - Ellära

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Film 1 - Laddning, krafter, potential

# %%
display(YouTubeVideo("-Rb9guSEeVE"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 2 - Spänning och ström

# %%
display(YouTubeVideo("u4FpbaMW5sk"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 3 - Kirchhoffs lagar

# %%
display(YouTubeVideo("m4jzgqZu-4s"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 4 - Ohms lag  $R=U/I \ [\Omega]$

# %%
display(YouTubeVideo("G3H5lKoWPpY"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 5 - Kapacitans $C=Q/U \ [F]$

# %%
display(YouTubeVideo("f_MZNsEqyQw"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# # Fördjupning

# %% [markdown]
# ## Film 6 - Induktans

# %%
display(YouTubeVideo("ukBFPrXiKWA"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Film 7 - Transistorer

# %%
display(YouTubeVideo("7ukDKVHnac4"))

# %% [markdown]
# #### Anteckningar
# ...
