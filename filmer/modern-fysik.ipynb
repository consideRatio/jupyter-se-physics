# %% [markdown]
# # Modern fysik

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Kärnfysik

# %% [markdown]
# ### Kärnfysik

# %%
display(YouTubeVideo("r40h66qiF5I"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Strålning

# %%
display(YouTubeVideo("iTb_KRG6LXo"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Strålning

# %%
display(YouTubeVideo("J-hfoDy904E"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ## Relativitetsteori

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("ERgwVm9qWKA"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("A2JCoIGyGxc"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("eOCKNH0zaho"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("qhVgIW4_-AQ"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("zScn3tV9YPU"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("zScn3tV9YPU"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("AU_O9yrgwhk"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("ruRrVWHcgws"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# Xrqj88zQZJg - Einstein's Relativistic Train in a Tunnel Paradox: Special Relativity
#
# bjHLboK2M1g - Twin Paradox in General Relativity
#
# 1ENkP0h8nAg - Gravity's effect on the flow of time in General Relativity

# %% [markdown]
# ## Kvantmekanik

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("p7bzE1E5PMY"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# ### Film 4 -

# %%
display(YouTubeVideo("KKr91v7yLcM"))

# %% [markdown]
# #### Anteckningar
# ...

# %% [markdown]
# Kvantmekanik (ytterligare...)
# * v657Ylwh-_k - Quantum entanglement, bell inequality, epr paradox
# * iVpXrbZ4bnU - Quantum Mechanics: Animation explaining quantum physics
# * RF7dDt3tVmI - Quantum Tunneling
# * LZie2QC5Jbc - Quantum Operators
# * jvvkomcmyuo - Schrodinger's Equation
# * 3k5IWlVdMbo - Quantum Spin - Visualizing the physics and mathematics
# * sFRdVj4rrAE - Quantum Measurements are Entanglement

# %% [markdown]
# Partikelfysik
# * 1sQX1st5bbw - Neutron Generators using Particle Accelerators

# %% [markdown]
# Generell relativitetsteori
# * gcvq1DAM-DE - Gravitational Time Dilation causes gravitational “attraction.”
